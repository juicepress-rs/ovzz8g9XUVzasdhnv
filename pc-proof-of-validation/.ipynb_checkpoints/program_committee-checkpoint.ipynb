# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.gridspec import GridSpec
from matplotlib import rc

# %%
findings = pd.read_csv("validation_proof_of_genuity.csv", index_col=0)
findings
# Out:
#      manufacturer                            device_name    firmware_version  \
# 0         NETGEAR                                 WAC510             9.9.6.8
# 28        NETGEAR                                 WAX210            1.1.0.34
# 29        TP-Link                         Archer AX53 V2              240123
# 30        TP-Link                         Archer AX58 V2              240123
# 167      Ubiquiti                       UISP Switch Plus              1.10.2
# ...           ...                                    ...                 ...
# 8678      TP-Link                        Archer C1200 V1              220517
# 8679      TP-Link                        Archer MR600 V2  1.8.0 Build 240716
# 8695     Ubiquiti  EdgeRouter ER-X/ER-X-SFP/EP-R6/ER-10X               3.0.0
# 8696     Ubiquiti                             UFiber OLT              v4.5.3
# 8697     Ubiquiti              UFiber OLT recovery image              v4.1.0
#
#      release_date         file_name  \
# 0      2025-04-21          lighttpd
# 28     2025-07-25  dbus-launch.real
# 29     2024-03-06           openvpn
# 30     2024-03-06           openvpn
# 167    2025-08-01        scriptlive
# ...           ...               ...
# 8678   2022-09-08   samba_multicall
# 8679   2024-09-24       dbus-launch
# 8695   2025-07-29      dpkg-trigger
# 8696   2023-08-02      dpkg-trigger
# 8697   2019-11-26      dpkg-trigger
#
#                                               source_fs  juiciness  \
# 0     1085fbddfaa8c46f7994a80a741d3d05017bf6b8036d04...   3.628314
# 28    45a0d2831d11d3a7b2b2820eb732e5e69e5d6ce4af8c01...   8.000000
# 29    3d4831b93b4e00a7a79517ed05652047c810f9c560c0af...   4.220000
# 30    5e0075c984fac39f83314fc1b9e62a630b75e1aebec48a...   4.220000
# 167   da30e711e3a3d016a5c5e9b02bfec4b78621e80d4f631a...   3.954565
# ...                                                 ...        ...
# 8678  ec116999612ee7065fdb89db19d60308d9a5991a7801a1...   8.142857
# 8679  c7c28c98da97710cf55f8fdd2a7b48df2141ef432e6229...   3.425887
# 8695  fd4f42cd786167ed40f3b12b1c60dfa5c8f380ab60222e...   4.898413
# 8696  c452b3c0114921fd7b719966ac28be0b332d154a0bc88b...   4.898413
# 8697  903a0f7411445449eda1a647f0930413bad2a258c643ff...   4.898413
#
#                                                  sha256  cmdi_closure_id  \
# 0     0035659ffcb56a3035901b2952326869ed550115d09f83...             6616
# 28    0130bc77460150b483a7f6ef7b5db35fbd76d2aee6e708...             4162
# 29    015320abc48cece5e968361e3045829d448c177136080f...             1459
# 30    015320abc48cece5e968361e3045829d448c177136080f...              786
# 167   023e0d4336434d9fa52087468530e878d8b01f7aed445c...             5318
# ...                                                 ...              ...
# 8678  ff11299db4ad2499eb910d49ee3dae0c8a1b5282b1d4af...             3955
# 8679  ff15b9cf8a665a5df5ac16a9610548b7e8c6fc69ea029a...             6470
# 8695  ff5d0112935cc0485e29406b686234512be2fa7460cccd...             6260
# 8696  ff5d0112935cc0485e29406b686234512be2fa7460cccd...             2268
# 8697  ff5d0112935cc0485e29406b686234512be2fa7460cccd...             1309
#
#       reachable_from_main  ...  \
# 0                    True  ...
# 28                   True  ...
# 29                  False  ...
# 30                  False  ...
# 167                  True  ...
# ...                   ...  ...
# 8678                False  ...
# 8679                 True  ...
# 8695                False  ...
# 8696                False  ...
# 8697                False  ...
#
#                                                    dupe  \
# 0     True___False___SHELL___execve___config_parse_f...
# 28                 True___False___SHELL___execvp___main
# 29                           False___False___peer_cert_
# 30                                     False___False___
# 167                True___False___SHELL___execlp___main
# ...                                                 ...
# 8678  False___False___LIBSMB_PROG___system___sub_17a...
# 8679          True___False___ARGV_SHELL___execvp___main
# 8695        False___False___SHELL___execlp___sub_40d814
# 8696        False___False___SHELL___execlp___sub_40d814
# 8697        False___False___SHELL___execlp___sub_40d814
#
#                                                firmware functional_tp  \
# 0     1085fbddfaa8c46f7994a80a741d3d05017bf6b8036d04...          True
# 28    45a0d2831d11d3a7b2b2820eb732e5e69e5d6ce4af8c01...          True
# 29    3d4831b93b4e00a7a79517ed05652047c810f9c560c0af...         False
# 30    5e0075c984fac39f83314fc1b9e62a630b75e1aebec48a...         False
# 167   da30e711e3a3d016a5c5e9b02bfec4b78621e80d4f631a...          True
# ...                                                 ...           ...
# 8678  ec116999612ee7065fdb89db19d60308d9a5991a7801a1...          True
# 8679  c7c28c98da97710cf55f8fdd2a7b48df2141ef432e6229...          True
# 8695  fd4f42cd786167ed40f3b12b1c60dfa5c8f380ab60222e...          True
# 8696  c452b3c0114921fd7b719966ac28be0b332d154a0bc88b...          True
# 8697  903a0f7411445449eda1a647f0930413bad2a258c643ff...          True
#
#      intended_behavior_documented  \
# 0                            True
# 28                           True
# 29                           True
# 30                           True
# 167                          True
# ...                           ...
# 8678                         True
# 8679                         True
# 8695                         True
# 8696                         True
# 8697                         True
#
#                                 intended_behavior_proof injection_class  \
# 0     https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 28    https://dbus.freedesktop.org/doc/dbus-launch.1...              PD
# 29    https://openvpn.net/community-docs/community-a...               -
# 30    https://openvpn.net/community-docs/community-a...               -
# 167   https://www.man7.org/linux/man-pages/man1/scri...              PD
# ...                                                 ...             ...
# 8678  https://linux.die.net/man/1/smbclient#:~:text=...              SI
# 8679  https://www.gnu.org/software/coreutils/manual/...              PD
# 8695  https://linux.die.net/man/1/dpkg#:~:text=The%2...              PD
# 8696  https://linux.die.net/man/1/dpkg#:~:text=The%2...              PD
# 8697  https://linux.die.net/man/1/dpkg#:~:text=The%2...              PD
#
#      verified_oss_package    __bug_id  __urgency_class juiciness_bucket
# 0                lighttpd  rc-cb4e022             NONE              4.0
# 28                   dbus  rc-b71aa8b             NONE              8.0
# 29                openvpn  rc-73c3a72             NONE              4.0
# 30                openvpn  rc-73c3a72             NONE              4.0
# 167            util-linux  rc-57bc3b7             NONE              4.0
# ...                   ...         ...              ...              ...
# 8678               libsmb  rc-83f6a84             NONE              8.0
# 8679            coreutils  rc-3eeb2c7             NONE              3.0
# 8695                 dpkg  rc-541bf0b             NONE              5.0
# 8696                 dpkg  rc-541bf0b             NONE              5.0
# 8697                 dpkg  rc-541bf0b             NONE              5.0
#
# [2491 rows x 25 columns]

# %%
mask = findings["functional_tp"] == True
tp_findings = findings[mask]
fp_findings = findings[~mask]

print(findings[findings["juiciness_bucket"] == 11])

# there are only a hand full of findings in bucket 11, move them to 10
tp_findings.loc[tp_findings["juiciness_bucket"] == 11, "juiciness_bucket"] = 10
# Out:
#      manufacturer  device_name   firmware_version release_date      file_name  \
# 5424         ASUS    DSL-AC52U       1.1.2.3_1000   2024-12-27  asus_lighttpd
# 5425         ASUS    DSL-AC55U       1.1.2.3_1000   2024-12-27  asus_lighttpd
# 5426         ASUS    DSL-AC56U       1.1.2.3_1000   2024-12-27  asus_lighttpd
# 5427         ASUS  DSL-N55U_C1        1.1.2.3_792   2024-01-09  asus_lighttpd
# 5428         ASUS  DSL-N55U D1        1.1.2.3_792   2024-01-09  asus_lighttpd
# 5429         ASUS     DSL-N17U        1.1.2.3_792   2023-12-26  asus_lighttpd
# 5430         ASUS     RT-AC55U  3.0.0.4.382.52236   2020-06-04  asus_lighttpd
# 5431         ASUS   RT-AC55UHP  3.0.0.4.382.52236   2020-06-04  asus_lighttpd
# 5432         ASUS    BRT-AC828  3.0.0.4.382.70348   2020-04-09  asus_lighttpd
#
#                                               source_fs  juiciness  \
# 5424  eaac2ace86eba958fa89c28bf2afa3f94838245018b727...       11.0
# 5425  717fa6f263f219e6a47d4482a71dbd954a60113e916ce7...       11.0
# 5426  ecbf600eeba2ea6770d88e3dbadc0990cf8b6c4d8640a4...       11.0
# 5427  39ce728346eec60691d55063fe26cae654d1542a66cfdc...       11.0
# 5428  67e6211c96951d1f29df7da905228b24e6f7a47156e7e5...       11.0
# 5429  fd20cc528aca9b00062930060f3a5c75664b66c573a976...       11.0
# 5430  ad3012b472f72263f17cc379376bfa65f36a7771bd479f...       11.0
# 5431  fb9aa75ebe73da086b5d7db1ade18961a4aa23f074e182...       11.0
# 5432  fa0545aab27413577120b69f124f1388cd831d28ea9ae4...       11.0
#
#                                                  sha256  cmdi_closure_id  \
# 5424  8eb845982b711de361cae313573634c3971e341970f943...             8665
# 5425  8eb845982b711de361cae313573634c3971e341970f943...              216
# 5426  8eb845982b711de361cae313573634c3971e341970f943...             1066
# 5427  8eb845982b711de361cae313573634c3971e341970f943...             3681
# 5428  8eb845982b711de361cae313573634c3971e341970f943...             1775
# 5429  8eb845982b711de361cae313573634c3971e341970f943...             1969
# 5430  8eb845982b711de361cae313573634c3971e341970f943...             1299
# 5431  8eb845982b711de361cae313573634c3971e341970f943...              841
# 5432  8eb845982b711de361cae313573634c3971e341970f943...             7824
#
#       reachable_from_main  ...  \
# 5424                 True  ...
# 5425                 True  ...
# 5426                 True  ...
# 5427                 True  ...
# 5428                 True  ...
# 5429                 True  ...
# 5430                 True  ...
# 5431                 True  ...
# 5432                 True  ...
#
#                                                    dupe  \
# 5424  True___False___SHELL___execl___config_parse_cm...
# 5425  True___False___SHELL___execl___config_parse_cm...
# 5426  True___False___SHELL___execl___config_parse_cm...
# 5427  True___False___SHELL___execl___config_parse_cm...
# 5428  True___False___SHELL___execl___config_parse_cm...
# 5429  True___False___SHELL___execl___config_parse_cm...
# 5430  True___False___SHELL___execl___config_parse_cm...
# 5431  True___False___SHELL___execl___config_parse_cm...
# 5432  True___False___SHELL___execl___config_parse_cm...
#
#                                                firmware functional_tp  \
# 5424  eaac2ace86eba958fa89c28bf2afa3f94838245018b727...          True
# 5425  717fa6f263f219e6a47d4482a71dbd954a60113e916ce7...          True
# 5426  ecbf600eeba2ea6770d88e3dbadc0990cf8b6c4d8640a4...          True
# 5427  39ce728346eec60691d55063fe26cae654d1542a66cfdc...          True
# 5428  67e6211c96951d1f29df7da905228b24e6f7a47156e7e5...          True
# 5429  fd20cc528aca9b00062930060f3a5c75664b66c573a976...          True
# 5430  ad3012b472f72263f17cc379376bfa65f36a7771bd479f...          True
# 5431  fb9aa75ebe73da086b5d7db1ade18961a4aa23f074e182...          True
# 5432  fa0545aab27413577120b69f124f1388cd831d28ea9ae4...          True
#
#      intended_behavior_documented  \
# 5424                         True
# 5425                         True
# 5426                         True
# 5427                         True
# 5428                         True
# 5429                         True
# 5430                         True
# 5431                         True
# 5432                         True
#
#                                 intended_behavior_proof injection_class  \
# 5424  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5425  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5426  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5427  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5428  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5429  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5430  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5431  https://pubs.opengroup.org/onlinepubs/96999197...              PD
# 5432  https://pubs.opengroup.org/onlinepubs/96999197...              PD
#
#      verified_oss_package    __bug_id  __urgency_class juiciness_bucket
# 5424             lighttpd  rc-cb4e022             NONE             11.0
# 5425             lighttpd  rc-cb4e022             NONE             11.0
# 5426             lighttpd  rc-cb4e022             NONE             11.0
# 5427             lighttpd  rc-cb4e022             NONE             11.0
# 5428             lighttpd  rc-cb4e022             NONE             11.0
# 5429             lighttpd  rc-cb4e022             NONE             11.0
# 5430             lighttpd  rc-cb4e022             NONE             11.0
# 5431             lighttpd  rc-cb4e022             NONE             11.0
# 5432             lighttpd  rc-cb4e022             NONE             11.0
#
# [9 rows x 25 columns]

# %%
def get_ratios(dedup=False):
    # proof of intended behavior is present
    def get_ratio(mask, dedup=False):
        yes = tp_findings[mask]
        no = tp_findings[~mask]
        if dedup:
            yes = yes.drop_duplicates(["__bug_id", "source_fs"])
            no = no.drop_duplicates(["__bug_id", "source_fs"])
        yes = yes.groupby(["juiciness_bucket","source_fs"])["manufacturer"].count().groupby("juiciness_bucket").sum().to_frame().rename(columns={"manufacturer": "count"})
        no = no.groupby(["juiciness_bucket","source_fs"])["manufacturer"].count().groupby("juiciness_bucket").sum().to_frame().rename(columns={"manufacturer": "count"})
        
        ratio = yes["count"].div(yes["count"].add(no["count"], fill_value=0), fill_value=0)
        return ratio
    
    
    labels = [
        "\\textbf{E}vidence of Intended Behavior Avail.",
        "\\textbf{C}onvenience Wrapper Usage",
        "\\textbf{K}nown Software Packages",
        "\\textbf{P}rocess Control (CWE-114)",
        "\\textbf{A}rgument Injection (CWE-88)",
        "\\textbf{O}S Command Injection (CWE-78)"
    ]
    
    masks = [
        tp_findings["intended_behavior_documented"] == True,
        ~tp_findings["sink"].str.contains("exec"),
        tp_findings["verified_oss_package"] != "-",
        tp_findings["injection_class"] == "PD",
        tp_findings["injection_class"] == "AI",
        tp_findings["injection_class"] == "SI",
    ]

    ratios = pd.DataFrame({}, index=list(range(0,11)))

    ratios.index.name = "juiciness_bucket"

    for label, mask in zip(labels, masks):
        ratios[label] = get_ratio(mask, dedup).fillna(0.0)

    return ratios.dropna()

ratios = get_ratios(dedup=True)
ratios
# Out:
#                   \textbf{E}vidence of Intended Behavior Avail.  \
# juiciness_bucket
# 1                                                           1.0
# 2                                                           1.0
# 3                                                           1.0
# 4                                                           1.0
# 5                                                           1.0
# 6                                                           1.0
# 7                                                           1.0
# 8                                                           1.0
# 9                                                           1.0
# 10                                                          1.0
#
#                   \textbf{C}onvenience Wrapper Usage  \
# juiciness_bucket
# 1                                           0.000000
# 2                                           0.007353
# 3                                           0.005076
# 4                                           0.020057
# 5                                           0.000000
# 6                                           0.027397
# 7                                           0.036082
# 8                                           0.341463
# 9                                           0.013514
# 10                                          0.000000
#
#                   \textbf{K}nown Software Packages  \
# juiciness_bucket
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
# 5                                              1.0
# 6                                              1.0
# 7                                              1.0
# 8                                              1.0
# 9                                              1.0
# 10                                             1.0
#
#                   \textbf{P}rocess Control (CWE-114)  \
# juiciness_bucket
# 1                                           1.000000
# 2                                           0.992647
# 3                                           0.959391
# 4                                           0.971347
# 5                                           0.994764
# 6                                           0.890411
# 7                                           0.948454
# 8                                           0.658537
# 9                                           0.986486
# 10                                          1.000000
#
#                   \textbf{A}rgument Injection (CWE-88)  \
# juiciness_bucket
# 1                                             0.000000
# 2                                             0.000000
# 3                                             0.000000
# 4                                             0.000000
# 5                                             0.000000
# 6                                             0.000000
# 7                                             0.010309
# 8                                             0.000000
# 9                                             0.000000
# 10                                            0.000000
#
#                   \textbf{O}S Command Injection (CWE-78)
# juiciness_bucket
# 1                                               0.000000
# 2                                               0.007353
# 3                                               0.005076
# 4                                               0.028653
# 5                                               0.005236
# 6                                               0.109589
# 7                                               0.041237
# 8                                               0.341463
# 9                                               0.013514
# 10                                              0.000000

# %%
fig = plt.figure(
    figsize=(8, 6),
)

gs = GridSpec(2, 1, height_ratios=[1, 3])

ax_total = fig.add_subplot(gs[0])
ax_line = fig.add_subplot(gs[1], sharex=ax_total)

x = np.arange(1, 11)

cmap = sns.color_palette("colorblind")

# dist plot total / dedup

fp_count = fp_findings["juiciness_bucket"].value_counts().fillna(0)
tp_count = tp_findings["juiciness_bucket"].value_counts().fillna(0)
counts_total = fp_count.add(tp_count, fill_value=0).to_frame()


ax_line.axvline(6, linestyle="-", color="black", linewidth=3)
ax_line.axvline(7, linestyle="-", color="black", linewidth=3)
ax_line.set_axisbelow(True)
ax_line.grid(True, zorder=1)


ax_total.set_axisbelow(True)
ax_total.axvline(6, linestyle="-", color="black", linewidth=3, zorder=10)
ax_total.axvline(7, linestyle="-", color="black", linewidth=3, zorder=10)
ax_total.grid(True)

ax_total.bar(x, counts_total["count"], color=cmap[1], edgecolor="black", linewidth=1, label="All Findings (TP+FP; $\\Sigma = 8,702)$", zorder=11)

fp_count = fp_findings.drop_duplicates(["__bug_id", "source_fs"])["juiciness_bucket"].value_counts().fillna(0)
tp_count = tp_findings.drop_duplicates(["__bug_id", "source_fs"])["juiciness_bucket"].value_counts().fillna(0)
counts_dedup = fp_count.add(tp_count, fill_value=0).to_frame()
ax_total.bar(x, counts_dedup["count"], color=cmap[-1], edgecolor="black", linewidth=1, label="Deduplicated (TP; $\\Sigma = 4,357$)", zorder=12)

handles, labels = ax_total.get_legend_handles_labels()


ax_total.legend(
    handles,
    labels,
    loc="upper center",
    fontsize=14,
    ncol=2,
    bbox_to_anchor=(0.45, 1.45),
)

line_palette = [cmap[0], "black", cmap[2], "gray", cmap[5], cmap[3],  "black",  cmap[1], cmap[3]]

ratios.plot(
    kind="line",
    markeredgecolor="black",
    markersize=8,
    markeredgewidth=1,
    style=["-o", "-o", "-o", "-s", "-s", "-s"],
    linewidth=2,
    color=line_palette,
    ax=ax_line, grid=True, legend=False)

handles, labels = ax_line.get_legend_handles_labels()

group_enrichment = [0, 2, 1]
group_bugs = [3, 4, 5]

ax_total.text(6.5, 2100, "Overlap", color="black", fontweight="heavy", fontsize=15, ha="center", va="top", rotation=45)



ax_line.add_artist(ax_line.legend(
    [handles[i] for i in group_enrichment],
    [labels[i] for i in group_enrichment],
    title="Findings: Properties",
    loc="lower left",
    fontsize=14,
    #ncol=2,
    bbox_to_anchor=(-0.145, -0.58),
))

ax_line.legend(
    [handles[i] for i in group_bugs],
    [labels[i] for i in group_bugs],
    title="Findings: Classification",
    fontsize=14,
    loc="lower left",
    ncol=1,
    bbox_to_anchor=(0.45, -0.58),
)


ax_total.set_yticks([0, 1000, 2000])

ax_total.set_ylabel("Findings [\\#]")
ax_total.set_xlim(0.6, 10.5)
ax_line.set_yticks([0.1 * x for x in range(0, 11)])
ax_line.set_xticks(range(1, 11))
ax_line.set_xlabel("Buckets [Juiciness]")
ax_line.set_ylabel("Property Share [Rel.]")

plt.savefig("juicepress_main_results_MOCK.pdf", bbox_inches="tight")

plt.show()
# line plot

# %%
share_df = tp_findings.groupby(['juiciness_bucket', '__urgency_class']).size().unstack(fill_value=0)
share_df = tp_findings.drop_duplicates(subset=["__bug_id", "source_fs"]).groupby(['juiciness_bucket', '__urgency_class']).size().unstack(fill_value=0)
share_df = share_df.div(share_df.sum(axis=1), axis=0)  # convert counts to percentages
share_df = share_df[["NONE"]].rename(columns={"NONE": "Informative"})
share_df.index = share_df.index.astype(int)
print(share_df)
# Out:
# __urgency_class   Informative
# juiciness_bucket
# 1                         1.0
# 2                         1.0
# 3                         1.0
# 4                         1.0
# 5                         1.0
# 6                         1.0
# 7                         1.0
# 8                         1.0
# 9                         1.0
# 10                        1.0

# %%
ax = share_df.plot(kind='bar', width=0.6, stacked=True, figsize=(10,3), edgecolor="black", linewidth=1, color=["#b9b9b9", cmap[2], cmap[1], cmap[3], cmap[4]], legend=False)

ax.legend(
    fontsize=14,
    loc="upper center",
    ncol=5,
    bbox_to_anchor=(0.5, 1.2),  
)

ax.set_axisbelow(True)
ax.grid(True, zorder=-4)
ax.tick_params(axis="x", labelrotation=0)
ax.set_yticks([0.1 * x for x in range(0, 11)])
ax.set_ylabel("Share [Rel.]")
ax.set_xlabel("Bucket [Juiciness]")
ax.axvline(4.5, linestyle="-", color="black", linewidth=3)
ax.axvline(6.5, linestyle="-", color="black", linewidth=3)


plt.savefig("juicepress_criticality_MOCK.pdf", bbox_inches="tight")
plt.show()
